# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 14.89461756   3.49726698  29.23228853   0.49843744   5.74802      0.        ]
# [ 9.07095849  4.77470512  3.11160313]
# [ 0.25654794 -0.17164286  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =  -1.121 (best =   0.053), noise_scale = 3.2625

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
'''
Include trajectory plots
'''
## TODO: Train your agent here.
import sys
import pandas as pd
from agents.agent_new2 import DDPG
from task_new2 import Task

num_episodes = 500
init_pose = np.array([0., 0., 50., 0., 0., 0.])
init_vel = np.array([0., 0., 0.])
init_angle_velocities = np.array([0., 0., 0.])
target_pose = np.array([0., 0., 0., 0., 0., 0.])
target_vel = np.array([0., 0., 0.])
task = Task(init_pose=init_pose, init_vel=init_vel, init_angle_velocities=init_angle_velocities, target_pose=target_pose, target_vel=target_vel)
agent = DDPG(task)
avg_episode_rewards = []
file_output = 'data2.txt'


labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}



with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)

    for i_episode in range(1, num_episodes+1):
        
        print("i_episode: " + str(i_episode))
        
        state = agent.reset_episode() # start a new episode
        time = 0
        total_episode_reward = 0
        count = 0
    

    
        while True:
            action = agent.act(state) 
            next_state, reward, done = task.step(action)
        
            if i_episode == num_episodes: #only write last episode with fully trained actor and critic networks
                to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
                for ii in range(len(labels)):
                    results[labels[ii]].append(to_write[ii])
                writer.writerow(to_write)
         
            total_episode_reward += reward
            count += 1
        
            agent.step(action, reward, next_state, done)
            state = next_state
            if done:
                break
            time += 1
    
        
        avg_episode_rewards.append(total_episode_reward/count)
        
        print("avg_episode_reward: " + str(total_episode_reward/count))
        
        sys.stdout.flush()
# Out:
# i_episode: 1
# avg_episode_reward: -39.3382643398
# i_episode: 2
# avg_episode_reward: -40.1408873961
# i_episode: 3
# avg_episode_reward: -41.4072306635
# i_episode: 4
# avg_episode_reward: -39.5183381036
# i_episode: 5
# avg_episode_reward: -39.3084192084
# i_episode: 6
# avg_episode_reward: -37.621541035
# i_episode: 7
# avg_episode_reward: -42.0922348899
# i_episode: 8
# avg_episode_reward: -103.347073369
# i_episode: 9
# avg_episode_reward: -45.8660604456
# i_episode: 10
# avg_episode_reward: -107.874799122
# i_episode: 11
# avg_episode_reward: -40.0864720093
# i_episode: 12
# avg_episode_reward: -39.8422443554
# i_episode: 13
# avg_episode_reward: -39.7801413046
# i_episode: 14
# avg_episode_reward: -39.6465693532
# i_episode: 15
# avg_episode_reward: -39.5795773518
# i_episode: 16
# avg_episode_reward: -44.1406200946
# i_episode: 17
# avg_episode_reward: -40.1193266927
# i_episode: 18
# avg_episode_reward: -44.107797194
# i_episode: 19
# avg_episode_reward: -39.126523146
# i_episode: 20
# avg_episode_reward: -39.1154416364
# i_episode: 21
# avg_episode_reward: -39.1016619552
# i_episode: 22
# avg_episode_reward: -40.0048076428
# i_episode: 23
# avg_episode_reward: -38.9277781995
# i_episode: 24
# avg_episode_reward: -39.1260008014
# i_episode: 25
# avg_episode_reward: -39.6876328497
# i_episode: 26
# avg_episode_reward: -38.0217259322
# i_episode: 27
# avg_episode_reward: -60.669519912
# i_episode: 28
# avg_episode_reward: -39.2672874389
# i_episode: 29
# avg_episode_reward: -51.2394530372
# i_episode: 30
# avg_episode_reward: -60.6643735556
# i_episode: 31
# avg_episode_reward: -60.56424198
# i_episode: 32
# avg_episode_reward: -60.6968040199
# i_episode: 33
# avg_episode_reward: -60.5876916104
# i_episode: 34
# avg_episode_reward: -60.5953693374
# i_episode: 35
# avg_episode_reward: -60.564934376
# i_episode: 36
# avg_episode_reward: -57.6561525182
# i_episode: 37
# avg_episode_reward: -60.3172103747
# i_episode: 38
# avg_episode_reward: -61.2110381556
# i_episode: 39
# avg_episode_reward: -60.5418459515
# i_episode: 40
# avg_episode_reward: -59.4377769168
# i_episode: 41
# avg_episode_reward: -60.9249404154
# i_episode: 42
# avg_episode_reward: -60.7290921578
# i_episode: 43
# avg_episode_reward: -61.2297332545
# i_episode: 44
# avg_episode_reward: -61.2717564159
# i_episode: 45
# avg_episode_reward: -48.2512804669
# i_episode: 46
# avg_episode_reward: -38.0905435248
# i_episode: 47
# avg_episode_reward: -39.3860130755
# i_episode: 48
# avg_episode_reward: -39.2877386663
# i_episode: 49
# avg_episode_reward: -39.3903868142
# i_episode: 50
# avg_episode_reward: -39.4287690239
# i_episode: 51
# avg_episode_reward: -39.3848729449
# i_episode: 52
# avg_episode_reward: -39.4277216299
# i_episode: 53
# avg_episode_reward: -39.4214302621
# i_episode: 54
# avg_episode_reward: -39.3944666738
# i_episode: 55
# avg_episode_reward: -39.4181913257
# i_episode: 56
# avg_episode_reward: -39.3968037046
# i_episode: 57
# avg_episode_reward: -39.4642138216
# i_episode: 58
# avg_episode_reward: -39.3885748052
# i_episode: 59
# avg_episode_reward: -39.384368232
# i_episode: 60
# avg_episode_reward: -39.3893757111
# i_episode: 61
# avg_episode_reward: -57.3028794669
# i_episode: 62
# avg_episode_reward: -41.8884826662
# i_episode: 63
# avg_episode_reward: -59.2646438943
# i_episode: 64
# avg_episode_reward: -61.1740971608
# i_episode: 65
# avg_episode_reward: -61.173333487
# i_episode: 66
# avg_episode_reward: -60.5709826669
# i_episode: 67
# avg_episode_reward: -53.6425158261
# i_episode: 68
# avg_episode_reward: -61.1971432282
# i_episode: 69
# avg_episode_reward: -61.0988360533
# i_episode: 70
# avg_episode_reward: -60.584277505
# i_episode: 71
# avg_episode_reward: -58.6682293681
# i_episode: 72
# avg_episode_reward: -51.0768838801
# i_episode: 73
# avg_episode_reward: -40.2443618929
# i_episode: 74
# avg_episode_reward: -41.0654451988
# i_episode: 75
# avg_episode_reward: -43.5317907085
# i_episode: 76
# avg_episode_reward: -61.1732142829
# i_episode: 77
# avg_episode_reward: -58.7831813249
# i_episode: 78
# avg_episode_reward: -60.7477288265
# i_episode: 79
# avg_episode_reward: -39.6299720463
# i_episode: 80
# avg_episode_reward: -37.6763870557
# i_episode: 81
# avg_episode_reward: -40.7156777929
# i_episode: 82
# avg_episode_reward: -39.3007639969
# i_episode: 83
# avg_episode_reward: -56.0159168843
# i_episode: 84
# avg_episode_reward: -50.8667500054
# i_episode: 85
# avg_episode_reward: -40.0291944504
# i_episode: 86
# avg_episode_reward: -40.0673576742
# i_episode: 87
# avg_episode_reward: -39.5824817267
# i_episode: 88
# avg_episode_reward: -40.0764929376
# i_episode: 89
# avg_episode_reward: -40.0225586073
# i_episode: 90
# avg_episode_reward: -40.2820438459
# i_episode: 91
# avg_episode_reward: -40.074358932
# i_episode: 92
# avg_episode_reward: -40.0777690732
# i_episode: 93
# avg_episode_reward: -39.9962804306
# i_episode: 94
# avg_episode_reward: -40.0260092423
# i_episode: 95
# avg_episode_reward: -39.9733453984
# i_episode: 96
# avg_episode_reward: -39.9787281046
# i_episode: 97
# avg_episode_reward: -39.9770263576
# i_episode: 98
# avg_episode_reward: -39.9771603382
# i_episode: 99
# avg_episode_reward: -39.9879556431
# i_episode: 100
# avg_episode_reward: -49.1620841602
# i_episode: 101
# avg_episode_reward: -67.0848139684
# i_episode: 102
# avg_episode_reward: -65.8195044079
# i_episode: 103
# avg_episode_reward: -62.0682329994
# i_episode: 104
# avg_episode_reward: -67.0950954033
# i_episode: 105
# avg_episode_reward: -67.0752914518
# i_episode: 106
# avg_episode_reward: -67.1741372378
# i_episode: 107
# avg_episode_reward: -66.9588833206
# i_episode: 108
# avg_episode_reward: -67.2083861174
# i_episode: 109
# avg_episode_reward: -67.1349201942
# i_episode: 110
# avg_episode_reward: -67.0034360716
# i_episode: 111
# avg_episode_reward: -67.0213928827
# i_episode: 112
# avg_episode_reward: -67.0832197595
# i_episode: 113
# avg_episode_reward: -67.1902507191
# i_episode: 114
# avg_episode_reward: -67.0998936524
# i_episode: 115
# avg_episode_reward: -67.1160766708
# i_episode: 116
# avg_episode_reward: -67.0794858566
# i_episode: 117
# avg_episode_reward: -67.0642410798
# i_episode: 118
# avg_episode_reward: -66.9996846755
# i_episode: 119
# avg_episode_reward: -66.9423547403
# i_episode: 120
# avg_episode_reward: -67.0269250065
# i_episode: 121
# avg_episode_reward: -67.2281692902
# i_episode: 122
# avg_episode_reward: -67.0893761715
# i_episode: 123
# avg_episode_reward: -67.0822994286
# i_episode: 124
# avg_episode_reward: -66.7447129776
# i_episode: 125
# avg_episode_reward: -67.1304236895
# i_episode: 126
# avg_episode_reward: -67.1233664604
# i_episode: 127
# avg_episode_reward: -67.0754546431
# i_episode: 128
# avg_episode_reward: -66.6421246197
# i_episode: 129
# avg_episode_reward: -65.6479807414
# i_episode: 130
# avg_episode_reward: -60.8656762144
# i_episode: 131
# avg_episode_reward: -53.8546773181
# i_episode: 132
# avg_episode_reward: -62.2851073087
# i_episode: 133
# avg_episode_reward: -49.1440933349
# i_episode: 134
# avg_episode_reward: -39.0374296758
# i_episode: 135
# avg_episode_reward: -39.0874208126
# i_episode: 136
# avg_episode_reward: -39.0983013496
# i_episode: 137
# avg_episode_reward: -39.0822762416
# i_episode: 138
# avg_episode_reward: -39.0582355378
# i_episode: 139
# avg_episode_reward: -39.0659370254
# i_episode: 140
# avg_episode_reward: -39.0843236713
# i_episode: 141
# avg_episode_reward: -39.0537701364
# i_episode: 142
# avg_episode_reward: -39.0581938734
# i_episode: 143
# avg_episode_reward: -39.0827320287
# i_episode: 144
# avg_episode_reward: -39.0544631196
# i_episode: 145
# avg_episode_reward: -39.097376197
# i_episode: 146
# avg_episode_reward: -39.0844148516
# i_episode: 147
# avg_episode_reward: -39.0374826187
# i_episode: 148
# avg_episode_reward: -39.0386723786
# i_episode: 149
# avg_episode_reward: -39.0598579201
# i_episode: 150
# avg_episode_reward: -39.1197442258
# i_episode: 151
# avg_episode_reward: -39.0574643316
# i_episode: 152
# avg_episode_reward: -39.0945755607
# i_episode: 153
# avg_episode_reward: -39.0894997517
# i_episode: 154
# avg_episode_reward: -39.0460525648
# i_episode: 155
# avg_episode_reward: -39.0850426154
# i_episode: 156
# avg_episode_reward: -39.0460780573
# i_episode: 157
# avg_episode_reward: -51.6424865754
# i_episode: 158
# avg_episode_reward: -44.7649332975
# i_episode: 159
# avg_episode_reward: -39.4776021272
# i_episode: 160
# avg_episode_reward: -64.6361538418
# i_episode: 161
# avg_episode_reward: -65.2905358981
# i_episode: 162
# avg_episode_reward: -65.0673193209
# i_episode: 163
# avg_episode_reward: -65.0037887235
# i_episode: 164
# avg_episode_reward: -65.8050126547
# i_episode: 165
# avg_episode_reward: -65.6352572225
# i_episode: 166
# avg_episode_reward: -64.2892022641
# i_episode: 167
# avg_episode_reward: -64.8515868371
# i_episode: 168
# avg_episode_reward: -65.2814693135
# i_episode: 169
# avg_episode_reward: -64.1629706146
# i_episode: 170
# avg_episode_reward: -64.6814724822
# i_episode: 171
# avg_episode_reward: -64.2361450337
# i_episode: 172
# avg_episode_reward: -65.4671352215
# i_episode: 173
# avg_episode_reward: -65.0766339307
# i_episode: 174
# avg_episode_reward: -65.0002307762
# i_episode: 175
# avg_episode_reward: -65.0678387568
# i_episode: 176
# avg_episode_reward: -64.3161082249
# i_episode: 177
# avg_episode_reward: -64.3179297969
# i_episode: 178
# avg_episode_reward: -65.7829625002
# i_episode: 179
# avg_episode_reward: -65.0587755745
# i_episode: 180
# avg_episode_reward: -62.5635510434
# i_episode: 181
# avg_episode_reward: -52.243643147
# i_episode: 182
# avg_episode_reward: -51.6685412114
# i_episode: 183
# avg_episode_reward: -51.6650395194
# i_episode: 184
# avg_episode_reward: -51.6756696572
# i_episode: 185
# avg_episode_reward: -52.4759287122
# i_episode: 186
# avg_episode_reward: -56.1822086596
# i_episode: 187
# avg_episode_reward: -55.7363448542
# i_episode: 188
# avg_episode_reward: -56.4534818272
# i_episode: 189
# avg_episode_reward: -56.1543697048
# i_episode: 190
# avg_episode_reward: -55.3408258151
# i_episode: 191
# avg_episode_reward: -54.8100631472
# i_episode: 192
# avg_episode_reward: -55.4668048117
# i_episode: 193
# avg_episode_reward: -56.4332011462
# i_episode: 194
# avg_episode_reward: -54.9270299427
# i_episode: 195
# avg_episode_reward: -51.7902431558
# i_episode: 196
# avg_episode_reward: -56.2515185789
# i_episode: 197
# avg_episode_reward: -51.9968368685
# i_episode: 198
# avg_episode_reward: -51.1691035761
# i_episode: 199
# avg_episode_reward: -39.084835254
# i_episode: 200
# avg_episode_reward: -38.7989677915
# i_episode: 201
# avg_episode_reward: -43.5126667776
# i_episode: 202
# avg_episode_reward: -39.0982781864
# i_episode: 203
# avg_episode_reward: -39.1682271606
# i_episode: 204
# avg_episode_reward: -53.6688042703
# i_episode: 205
# avg_episode_reward: -44.9011436809
# i_episode: 206
# avg_episode_reward: -54.3422482122
# i_episode: 207
# avg_episode_reward: -45.4621541818
# i_episode: 208
# avg_episode_reward: -39.7919051145
# i_episode: 209
# avg_episode_reward: -39.0871146027
# i_episode: 210
# avg_episode_reward: -39.0941847005
# i_episode: 211
# avg_episode_reward: -39.0542287327
# i_episode: 212
# avg_episode_reward: -39.0789519933
# i_episode: 213
# avg_episode_reward: -44.5293364984
# i_episode: 214
# avg_episode_reward: -39.46220243
# i_episode: 215
# avg_episode_reward: -40.8104445568
# i_episode: 216
# avg_episode_reward: -41.8257829095
# i_episode: 217
# avg_episode_reward: -39.0839050439
# i_episode: 218
# avg_episode_reward: -39.0777807074
# i_episode: 219
# avg_episode_reward: -39.0506682646
# i_episode: 220
# avg_episode_reward: -39.0822101926
# i_episode: 221
# avg_episode_reward: -39.0799933187
# i_episode: 222
# avg_episode_reward: -39.0682808309
# i_episode: 223
# avg_episode_reward: -39.0582021205
# i_episode: 224
# avg_episode_reward: -39.0557514509
# i_episode: 225
# avg_episode_reward: -39.0607905812
# i_episode: 226
# avg_episode_reward: -39.0753904809
# i_episode: 227
# avg_episode_reward: -39.0523069882
# i_episode: 228
# avg_episode_reward: -39.0992372654
# i_episode: 229
# avg_episode_reward: -39.0512419555
# i_episode: 230
# avg_episode_reward: -39.0745560913
# i_episode: 231
# avg_episode_reward: -39.0762513174
# i_episode: 232
# avg_episode_reward: -39.1071824523
# i_episode: 233
# avg_episode_reward: -39.039483435
# i_episode: 234
# avg_episode_reward: -39.0518995348
# i_episode: 235
# avg_episode_reward: -39.0852446948
# i_episode: 236
# avg_episode_reward: -39.0949285732
# i_episode: 237
# avg_episode_reward: -39.0902124481
# i_episode: 238
# avg_episode_reward: -39.0704189266
# i_episode: 239
# avg_episode_reward: -39.060135813
# i_episode: 240
# avg_episode_reward: -39.0761163235
# i_episode: 241
# avg_episode_reward: -39.0607163725
# i_episode: 242
# avg_episode_reward: -39.0877562833
# i_episode: 243
# avg_episode_reward: -39.0582071661
# i_episode: 244
# avg_episode_reward: -39.0679373503
# i_episode: 245
# avg_episode_reward: -39.068998405
# i_episode: 246
# avg_episode_reward: -39.0642923699
# i_episode: 247
# avg_episode_reward: -39.0905977142
# i_episode: 248
# avg_episode_reward: -39.0932151696
# i_episode: 249
# avg_episode_reward: -39.0612454214
# i_episode: 250
# avg_episode_reward: -39.0770638988
# i_episode: 251
# avg_episode_reward: -39.0786327388
# i_episode: 252
# avg_episode_reward: -39.0803265158
# i_episode: 253
# avg_episode_reward: -39.1010797846
# i_episode: 254
# avg_episode_reward: -39.0717026655
# i_episode: 255
# avg_episode_reward: -39.0984773385
# i_episode: 256
# avg_episode_reward: -39.0533020808
# i_episode: 257
# avg_episode_reward: -39.0838592854
# i_episode: 258
# avg_episode_reward: -39.0823962518
# i_episode: 259
# avg_episode_reward: -39.094466155
# i_episode: 260
# avg_episode_reward: -39.0770448983
# i_episode: 261
# avg_episode_reward: -39.0777034981
# i_episode: 262
# avg_episode_reward: -39.110019611
# i_episode: 263
# avg_episode_reward: -39.0731384428
# i_episode: 264
# avg_episode_reward: -39.0880688359
# i_episode: 265
# avg_episode_reward: -39.1003817338
# i_episode: 266
# avg_episode_reward: -39.0860114667
# i_episode: 267
# avg_episode_reward: -39.0473845516
# i_episode: 268
# avg_episode_reward: -39.0903021143
# i_episode: 269
# avg_episode_reward: -39.0642838261
# i_episode: 270
# avg_episode_reward: -39.0826311405
# i_episode: 271
# avg_episode_reward: -39.0744838756
# i_episode: 272
# avg_episode_reward: -39.0630234975
# i_episode: 273
# avg_episode_reward: -39.0684758007
# i_episode: 274
# avg_episode_reward: -39.091017217
# i_episode: 275
# avg_episode_reward: -39.0760557146
# i_episode: 276
# avg_episode_reward: -39.0656785306
# i_episode: 277
# avg_episode_reward: -39.0752088519
# i_episode: 278
# avg_episode_reward: -39.0763087479
# i_episode: 279
# avg_episode_reward: -39.0064869565
# i_episode: 280
# avg_episode_reward: -39.0719777619
# i_episode: 281
# avg_episode_reward: -39.1016021393
# i_episode: 282
# avg_episode_reward: -39.0464872955
# i_episode: 283
# avg_episode_reward: -39.0927658332
# i_episode: 284
# avg_episode_reward: -39.0579146639
# i_episode: 285
# avg_episode_reward: -39.0667711203
# i_episode: 286
# avg_episode_reward: -39.0861170528
# i_episode: 287
# avg_episode_reward: -39.0601481006
# i_episode: 288
# avg_episode_reward: -39.0905006159
# i_episode: 289
# avg_episode_reward: -39.0654839666
# i_episode: 290
# avg_episode_reward: -39.0922952448
# i_episode: 291
# avg_episode_reward: -39.1133230287
# i_episode: 292
# avg_episode_reward: -39.0726513905
# i_episode: 293
# avg_episode_reward: -39.0819864656
# i_episode: 294
# avg_episode_reward: -39.0486936024
# i_episode: 295
# avg_episode_reward: -39.0936416015
# i_episode: 296
# avg_episode_reward: -39.0632799298
# i_episode: 297
# avg_episode_reward: -39.0732169353
# i_episode: 298
# avg_episode_reward: -39.0924530432
# i_episode: 299
# avg_episode_reward: -39.0911952364
# i_episode: 300
# avg_episode_reward: -39.0804874569
# i_episode: 301
# avg_episode_reward: -39.0582115587
# i_episode: 302
# avg_episode_reward: -39.0509208568
# i_episode: 303
# avg_episode_reward: -39.0786261794
# i_episode: 304
# avg_episode_reward: -39.1032967126
# i_episode: 305
# avg_episode_reward: -39.0827844441
# i_episode: 306
# avg_episode_reward: -39.0757903197
# i_episode: 307
# avg_episode_reward: -39.0715391712
# i_episode: 308
# avg_episode_reward: -39.0752053703
# i_episode: 309
# avg_episode_reward: -39.072746843
# i_episode: 310
# avg_episode_reward: -39.0844951447
# i_episode: 478
# avg_episode_reward: -39.0559439191
# i_episode: 479
# avg_episode_reward: -39.0951639826
# i_episode: 480
# avg_episode_reward: -39.0764660096
# i_episode: 481
# avg_episode_reward: -39.0435239122
# i_episode: 482
# avg_episode_reward: -39.096657661
# i_episode: 483
# avg_episode_reward: -39.0869637008
# i_episode: 484
# avg_episode_reward: -39.0674858692
# i_episode: 485
# avg_episode_reward: -39.0893481071
# i_episode: 486
# avg_episode_reward: -39.0958833034
# i_episode: 487
# avg_episode_reward: -39.0611959796
# i_episode: 488
# avg_episode_reward: -39.080811967
# i_episode: 489
# avg_episode_reward: -39.0807827041
# i_episode: 490
# avg_episode_reward: -39.0535815218
# i_episode: 491
# avg_episode_reward: -39.1114058656
# i_episode: 492
# avg_episode_reward: -39.0644568193
# i_episode: 493
# avg_episode_reward: -39.0601424319
# i_episode: 494
# avg_episode_reward: -39.1040889398
# i_episode: 495
# avg_episode_reward: -39.0826319886
# i_episode: 496
# avg_episode_reward: -39.1126459562
# i_episode: 497
# avg_episode_reward: -39.1001828141
# i_episode: 498
# avg_episode_reward: -39.0866527743
# i_episode: 499
# avg_episode_reward: -39.0927257638
# i_episode: 500
# avg_episode_reward: -39.0851270715

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
##Plot last-episode trajectory
plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
## TODO: Plot the rewards.
## TODO: Plot the rewards.
plt.plot(range(len(avg_episode_rewards)), avg_episode_rewards, label='Avg_Episode_Rewards')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**: I designed the reward function to land softly. I specified the reward function in order to ensure that deviations from target position (0,0,0) and target velocity (0,0,0) were punished, and also to ensure that the velocity only came into play as the quadcopter approached the target position. I originally tried the reward function
#
# reward = - alpha*(abs(self.sim.pose[:3] - self.target_pose[:3])).sum() - beta*(abs(self.sim.v[:3] - self.target_vel)).sum()/abs(self.sim.pose[:3] - self.target_pose[:3])).sum()
#
# but found in training that the reward function was behaving very strangely. I suspected that it might have to do with singular behavior of the reward function when approaching the target position, where the denominator in the second term goes to zero, so modified the reward function to
#
# - alpha*(abs(self.sim.pose[:3] - self.target_pose[:3])).sum() - np.exp(-beta*abs(self.sim.pose[:3] - self.target_pose[:3]).sum())*(abs(self.sim.v[:3] - self.target_vel)).sum()
#
# with alpha = .3, beta = .1. This yielded the desired training behavior.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
# - I tried a DDPG, which worked for certain parameter values and neural network architectures.
# - I chose to remain with the original hyperparameters for exploration gamma and tau since attempted deviations from these, particularly in exploration_theta and exploration_sigma, hurt performance.
# - For the actor and critic networks, I tried the following combinations:
#
# **1st pair of networks **
#
# Actor:
#         states = layers.Input(shape=(self.state_size,), name='states')
#         net = layers.Dense(units=32, activation='relu')(states)
#         net = layers.Dense(units=64, activation='relu')(net)
#         net = layers.Dense(units=32, activation='relu')(net)
#         raw_actions = layers.Dense(units=self.action_size, activation='sigmoid',
#             name='raw_actions')(net)
#
# Critic:
#         states = layers.Input(shape=(self.state_size,), name='states')
#         actions = layers.Input(shape=(self.action_size,), name='actions')
#
#         net_states = layers.Dense(units=32, activation='relu')(states)
#         net_states = layers.Dense(units=64, activation='relu')(net_states)
#
#         net_actions = layers.Dense(units=32, activation='relu')(actions)
#         net_actions = layers.Dense(units=64, activation='relu')(net_actions)
#
#         net = layers.Add()([net_states, net_actions])
#         net = layers.Activation('relu')(net)
#
#         Q_values = layers.Dense(units=1, name='q_values')(net)
#
# **2nd pair of networks**
#
# Actor:
#         states = layers.Input(shape=(self.state_size,), name='states')
#         net = layers.Dense(units=256, activation='relu')(states)
#         net = layers.BatchNormalization()(net)
#         net = layers.Activation("relu")(net)
#         net = layers.Dense(units=256, activation='relu')(net)
#         net = layers.BatchNormalization()(net)
#         net = layers.Activation("relu")(net)
#         net = layers.Dense(units=128, activation='relu')(net)
#         net = layers.BatchNormalization()(net)
#         net = layers.Activation("relu")(net)
#         net = layers.Dense(units=64, activation='relu')(net)
#         raw_actions = layers.Dense(units=self.action_size, activation='sigmoid',
#             name='raw_actions')(net)
#
# Critic:
#         states = layers.Input(shape=(self.state_size,), name='states')
#         actions = layers.Input(shape=(self.action_size,), name='actions')
#
#         net_states = layers.Dense(units=128, activation='relu')(states)
#         net_states = layers.BatchNormalization()(net_states)
#         net_states = layers.Activation('relu')(net_states)
#         net_states = layers.Dense(units=128, activation='relu')(net_states)
#         net_states = layers.BatchNormalization()(net_states)
#         net_states = layers.Activation('relu')(net_states)
#
#
#         net_actions = layers.Dense(units=128, activation='relu')(actions)
#         net_actions = layers.BatchNormalization()(net_actions)
#         net_actions = layers.Activation('relu')(net_actions)
#         net_actions = layers.Dense(units=128, activation='relu')(net_actions)
#
#         net = layers.Add()([net_states, net_actions])
#         net = layers.Activation('relu')(net)
#
#         Q_values = layers.Dense(units=1, name='q_values')(net)
#
# Increasing the complexity of the networks did not seem to markedly improve performance from the original simpler networks.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# - Once the reward function was properly specified, it was not too difficult a task to learn given the initial networks and parameters.
# - The learning curve improved very suddenly around episode 200.
# - The average episode reward over the last 10 episodes was around -40, which was very close to the peak performance over all episodes. Early in the training, the reward fluctuated to values as low as -110

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
# - Getting started was the hardest part - in particular, converting my abstract theoretical understanding of the algorithms into working code. The task I chose was to land smoothly, and I attempted to specify the reward function so that velocity-dependent terms only contributed when the quadcopter was close to the spatial origin. My original reward function generated strange plots of reward vs training episode, likely due to the singular denominator that diverged when the quadcopter approached the target position (the origin). After changing this reward function to avoid this behavior, I found that the training generally improved the reward. I then attempted make further adjustments to the actor and critic networks by increasing the number of nodes and layers and adding batch normalization; counterintuitively, this appeared to diminish performance somewhat. Increasing the value of sigma associated with OU noise from .2 to .4 completely disrupted the training of the network. Likewise, adjusting the value of theta from .15 to .1 (with the original sigma=.2) also appeared to spoil the training.
#
# - I found it interesting that increasing the complexity of the actor and critic networks didn't appear to do much to improve training, as I expected it would. Also, I did not expect that the adjustments I made to sigma and theta in the OU noise would do so much to disrupt training. In most attempts, the quadcopter's trajectory landed at the desired location, so there was little surprising there. However, further explorations would also plot the velocity and try further adjustments to the reward function in order to make the landing smoother.
